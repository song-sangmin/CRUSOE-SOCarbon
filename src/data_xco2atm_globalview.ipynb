# %% [markdown]
# Data Access
#
#
#
# - https://daac.ornl.gov/ISLSCP_II/guides/globalview_co2_point.html
# - Obspack documentation: https://gml.noaa.gov/ccgg/globalview/documentation.html

# %%
import os
import xarray as xr

# %%
filepath = '/Users/sangminsong/Library/CloudStorage/OneDrive-UW/Code/CRUSOE/data/globalview-atmco2/obspack_co2_1_GLOBALVIEWplus_v10.1_2024-11-13/data/nc/co2_cgo_surface-insitu_2_allvalid.nc'

# %%
atmos = xr.open_dataset(filepath)

# %%
atmos.value
# Out:
# <xarray.DataArray 'value' (obs: 159773)>
# array([0.000374, 0.000375, 0.000375, ..., 0.000424, 0.000421, 0.000419],
#       dtype=float32)
# Dimensions without coordinates: obs
# Attributes:
#     long_name:      measured_mole_fraction_of_trace_gas_in_dry_air
#     units:          mol mol-1
#     comment:        mole per mole of dry air
#     scale_comment:  WMO CO2 X2019

# %%
atmos.latitude
# Out:
# <xarray.DataArray 'latitude' (obs: 159773)>
# array([-40.683, -40.683, -40.683, ..., -40.683, -40.683, -40.683],
#       dtype=float32)
# Dimensions without coordinates: obs
# Attributes:
#     standard_name:  latitude
#     long_name:      sample_latitude_in_decimal_degrees
#     units:          degrees_north
#     comment:        Latitude at which air sample was collected.

# %%
atmos.datetime
# Out:
# <xarray.DataArray 'datetime' (obs: 159773)>
# array([b'2004-04-23T07:30:00Z', b'2004-04-23T08:30:00Z',
#        b'2004-04-23T09:30:00Z', ..., b'2023-12-31T21:30:00Z',
#        b'2023-12-31T22:30:00Z', b'2023-12-31T23:30:00Z'], dtype='|S100')
# Dimensions without coordinates: obs
# Attributes:
#     long_name:  air_sample_date_and_time_in_UTC
#     comment:    Air sample date and time in UTC ISO 8601 format. Time-average...
